# %%
from pyspark.sql.functions import (
    col,
    from_json,
    to_timestamp,
    hour,
    window,
    count,
    sum as spark_sum,
)

from pyspark.sql.types import (
    StructType,
    StructField,
    StringType,
    DoubleType,
    TimestampType,
)

transaction_schema = StructType([
    StructField("transaction_id", StringType(), True),
    StructField("card_id", StringType(), True),
    StructField("amount", DoubleType(), True),
    StructField("merchant_category", StringType(), True),
    StructField("country", StringType(), True),
    StructField("event_time", TimestampType(), True),
])




bronze = spark.read.table("northmart_dev.bronze.fraud_transactions")

parsed = (
        bronze
        .withColumn(
            "transaction",
            from_json(
                col("value"),
                None,
                {
                    "schemaLocationKey": "fraud_transaction_payload"
                }
            )
        )
        .select(
            "transaction.*",
            "partition",
            "offset",
            "kafka_timestamp"
        )
)

parsed.show(5)
# Out:
# ---------------------------------------------------------------------------
# PySparkTypeError                          Traceback (most recent call last)
# Cell In[18], line 37
#      33 parsed = (
#      34         bronze
#      35         .withColumn(
#      36             "transaction",
# ---> 37             from_json(
#      38                 col("value"),
#      39                 None,
#      40                 {
#
# File ~/northmart360/.venv/lib/python3.12/site-packages/pyspark/sql/utils.py:308, in try_remote_functions.<locals>.wrapped(*args, **kwargs)
#     305 if is_remote() and "PYSPARK_NO_NAMESPACE_SHARE" not in os.environ:
#     306     from pyspark.sql.connect import functions
# --> 308     return getattr(functions, f.__name__)(*args, **kwargs)
#     309 else:
#     310     return f(*args, **kwargs)
#
# File ~/northmart360/.venv/lib/python3.12/site-packages/pyspark/sql/connect/functions/builtin.py:2104, in from_json(col, schema, options)
#    2102     _schema = lit(schema.json())
#    2103 else:
# -> 2104     raise PySparkTypeError(
#    2105         errorClass="NOT_COLUMN_OR_DATATYPE_OR_STR",
#    2106         messageParameters={"arg_name": "schema", "arg_type": type(schema).__name__},
#    2107     )
#    2109 if options is None:
#    2110     return _invoke_function("from_json", _to_col(col), _schema)
#
# PySparkTypeError: [NOT_COLUMN_OR_DATATYPE_OR_STR] Argument `schema` should be a Column, str or DataType, but got NoneType.
